# %%
import sys
import pytesseract
from PIL import Image
from PIL import ImageFilter

# %%
def iswhite(value):
    if value == (255,255,255):
        return True

# Open the tree file, convert to b&w, extract tip ids with OCR

img = Image.open("/Users/alex/GitHub/TreeBark/Geraniales-tree.jpg")
img = img.convert('1')
img
# Out:
# <PIL.Image.Image image mode=1 size=4250x5500 at 0x10448D390>

# %%
print(pytesseract.image_to_string(img))
# Out:
# Pe|.fulgidum
# Pel.incrassatum
# Pel.echinatum
# Pel.nanum
# Pel.citronellum
# Pel.dichondrifolium
# Pel.exstipulatum
# Pel.australe
# Pel.cotyledonis
# Pel.hortorum
# Pel.transvaa|ense
# Pel.myrrhifo|ium
# Pel.tetragonum
# Ero.chrysanthum
# Ero.gruinum
# Ero.texanum
# Ero.cheilanthifolium
# Ero.trifo|ium
# Calmacrophylla
# Ger.incanum
# Ger.phaeum
# Germaderense
# Mon.emarginata
# Monmarlothii
# Hyp.bilobata
# Fra.sonchifolia
# Mel.vi|losus
